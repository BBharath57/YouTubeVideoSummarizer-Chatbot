# %% [markdown]
# # import

# %%
# !pip install youtube_transcript_api, langchian, langchain_core, langchain_community, langchain_huggingface, langchain_google_genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Invalid requirement: 'youtube_transcript_api,'

# %% [markdown]
# # Youtube Transcipt

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled

# %%
# method for extracting video id from the url by manual coding 

def extract_video_id(url: str) -> str:
    l = []

    if 'www.youtube.com' in url:
        for i in url.split('?'):
            l.append(i)
        return l[1][2:13]
        
    elif 'youtu.be' in url:
        for i in url.split('/'):
            l.append(i)
        return l[3][0:11]

# %%
# using urllib module we can extract video id easily 

from urllib.parse import urlparse, parse_qs

url = 'hhttps://www.youtube.com/watch?v=OivTPt5LQh0'
video_id = parse_qs(urlparse(url).query)['v'][0]
print(video_id)
# Out:
# OivTPt5LQh0

# %%
urlparse(url).query
# Out:
# 'v=OivTPt5LQh0'

# %%
parse_qs(urlparse(url).query)
# Out:
# {'v': ['OivTPt5LQh0']}

# %%
parse_qs(urlparse(url).query)['v'][0]
# Out:
# 'OivTPt5LQh0'

# %%
# transcript data below

# %%
link = 'https://www.youtube.com/watch?v=gm_lQG8fYjI&list=PLKnIA16_RmvaTbihpo4MtzVm4XOQa0ER0&index=20'
youtube_id = extract_video_id(link)
transcript = YouTubeTranscriptApi.get_transcript(video_id=youtube_id, languages=['en','ja','hi'])

# %%
transcript
# Out:
# [{'text': 'हाय गाइस, माय नेम इज नितीश एंड यू आर',
#   'start': 0.0,
#   'duration': 4.319},
#  {'text': 'वेलकम टू माय YouTube चैनल। इस वीडियो में',
#   'start': 2.0,
#   'duration': 4.0},
#  {'text': 'भी हम लोग अपना लैंग चेन प्लेलिस्ट',
#   'start': 4.319,
#   'duration': 4.24},
#  {'text': 'कंटिन्यू करेंगे। और यह जो वीडियो है, यह',
#   'start': 6.0,
#   'duration': 6.32},
#  {'text': 'इस प्लेलिस्ट का 18th और लास्ट वीडियो है।',
#   'start': 8.559,
#   'duration': 6.561},
#  {'text': 'एज ऑफ नाउ। हो सकता है फ्यूचर में मैं कुछ',
#   'start': 12.32,
#   'duration': 4.959},
#  {'text': 'और वीडियोस यहां पे ऐड करूं। बट जो मेरा',
#   'start': 15.12,
#   'duration': 4.239},
#  {'text': 'इनिशियल प्लान था जो मैंने आपके साथ',
#   'start': 17.279,
#   'duration': 4.241},
#  {'text': 'फर्स्ट वीडियो में शेयर किया था। उस प्लान',
#   'start': 19.359,
#   'duration': 4.241},
#  {'text': 'के अकॉर्डिंग आज का वीडियो इज़ गोइंग टू बी',
#   'start': 21.52,
#   'duration': 4.4},
# ...

# %%
len(transcript)
# Out:
# 1584

# %%
transcript[5]
# Out:
# {'text': 'एज ऑफ नाउ। हो सकता है फ्यूचर में मैं कुछ',
#  'start': 12.32,
#  'duration': 4.959}

# %%
transcript[5]['text']
# Out:
# 'एज ऑफ नाउ। हो सकता है फ्यूचर में मैं कुछ'

# %%
s = " ".join(i['text'] for i in transcript)

# %%
s
# Out:
# 'हाय गाइस, माय नेम इज नितीश एंड यू आर वेलकम टू माय YouTube चैनल। इस वीडियो में भी हम लोग अपना लैंग चेन प्लेलिस्ट कंटिन्यू करेंगे। और यह जो वीडियो है, यह इस प्लेलिस्ट का 18th और लास्ट वीडियो है। एज ऑफ नाउ। हो सकता है फ्यूचर में मैं कुछ और वीडियोस यहां पे ऐड करूं। बट जो मेरा इनिशियल प्लान था जो मैंने आपके साथ फर्स्ट वीडियो में शेयर किया था। उस प्लान के अकॉर्डिंग आज का वीडियो इज़ गोइंग टू बी द लास्ट वीडियो। अब एक बार मैं आपको बता देता हूं कि आज के वीडियो में हम क्या कवर करने वाले हैं। हम कवर करेंगे कि हम एआई एजेंट्स कैसे बना सकते हैं विद द हेल्प ऑफ लैंग चेन। ठीक है? तो पिछले दो वीडियोस में हमने टूल्स और टूल कॉलिंग का कांसेप्ट पढ़ा था जिसको हम यूज़ करेंगे आज के वीडियो में। अ और आज का जो वीडियो है वो मोस्टली दो पार्ट्स में डिवाइडेड है। इन द फर्स्ट पार्ट मैं आपको थोड़ा सा एक थ्योरिटिकल एंड कॉनसेप्चुअल इंट्रोडक्शन दूंगा कि एआई एजेंट्स होते क्या हैं? अह बहुत ज़्यादा डीप नहीं जाएंगे। ब्रीफली डिस्कस करेंगे। बट आपको एक यूज़ केस के थ्रू मैं समझाना चाहूंगा कि एआई एजेंट्स होते क्या हैं? और फिर इन द से
# ...

# %% [markdown]
# # Splitter

# %%
# now we have to split the text

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 200)

# %%
chunks = splitter.create_documents([s])

# %%
chunks
# Out:
# [Document(metadata={}, page_content='हाय गाइस, माय नेम इज नितीश एंड यू आर वेलकम टू माय YouTube चैनल। इस वीडियो में भी हम लोग अपना लैंग चेन प्लेलिस्ट कंटिन्यू करेंगे। और यह जो वीडियो है, यह इस प्लेलिस्ट का 18th और लास्ट वीडियो है। एज ऑफ नाउ। हो सकता है फ्यूचर में मैं कुछ और वीडियोस यहां पे ऐड करूं। बट जो मेरा इनिशियल प्लान था जो मैंने आपके साथ फर्स्ट वीडियो में शेयर किया था। उस प्लान के अकॉर्डिंग आज का वीडियो इज़ गोइंग टू बी द लास्ट वीडियो। अब एक बार मैं आपको बता देता हूं कि आज के वीडियो में हम क्या कवर करने वाले हैं। हम कवर करेंगे कि हम एआई एजेंट्स कैसे बना सकते हैं विद द हेल्प ऑफ लैंग चेन। ठीक है? तो पिछले दो वीडियोस में हमने टूल्स और टूल कॉलिंग का कांसेप्ट पढ़ा था जिसको हम यूज़ करेंगे आज के वीडियो में। अ और आज का जो वीडियो है वो मोस्टली दो पार्ट्स में डिवाइडेड है। इन द फर्स्ट पार्ट मैं आपको थोड़ा सा एक थ्योरिटिकल एंड कॉनसेप्चुअल इंट्रोडक्शन दूंगा कि एआई एजेंट्स होते क्या हैं? अह बहुत ज़्यादा डीप नहीं जाएंगे। ब्रीफली डिस्कस करेंगे। बट आपको एक यूज़ केस के थ्रू मैं समझाना चाहूंगा कि एआई ए
# ...

# %%
len(chunks)
# Out:
# 76

# %%
# chunks[8]

# %% [markdown]
# # Vectors

# %%
# now covert the chunks into vectors

# %%
from langchain_huggingface import HuggingFaceEmbeddings, ChatHuggingFace, HuggingFaceEndpoint

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
embed = GoogleGenerativeAIEmbeddings(model='models/embedding-001', google_api_key='AIzaSyCoqxDqLb8NYnoUnaMyPrNz9Y5wrZZQzWo')

# %%
embeddding = embed.embed_query('hi how are you?')

# %%
len(embeddding)
# Out:
# 768

# %%
from langchain_community.vectorstores import FAISS

# %%
Vectors = FAISS.from_documents(chunks, embed)

# %%
Vectors

# %%
Vectors.index_to_docstore_id
# Out:
# {0: 'deba1f21-e644-42a5-a678-33d7ee31303d',
#  1: '369ae668-f524-4033-8f28-691d44beba82',
#  2: 'e4ba4307-44f4-4833-a8cd-7bb34a6008f7',
#  3: 'bfc0a729-f69a-43ca-b0e1-7789eb5670ff',
#  4: '3a2a3888-b7fb-4b58-bb45-029da5c0fca0',
#  5: 'baa1ebd1-3434-4b0c-b4ee-f2096bb53558',
#  6: 'a9ddc9ca-4e00-42a3-83f9-23aa307fb951',
#  7: '2d978863-12ab-4413-94d3-dc04875c28ad',
#  8: '916e40cb-0759-4ad3-a9d2-2d82f8224232',
#  9: 'ab30fbdd-8f0c-4cdd-a0c2-14e7ca53a895',
#  10: 'e6ca78ad-b881-4a8a-87fb-3b7432aa9ea5',
#  11: '572c67d4-38f0-49e9-b794-8cc73625ffb1',
#  12: '5cfe81bd-3464-48c2-a0a5-9c2f7519aca8',
#  13: '8bf67f9f-5374-4212-9e7a-23de3babc23b',
#  14: '0db0de4e-a3a8-4df9-aefc-4a43b4d56fef',
#  15: 'd54b02f6-5146-4b02-aa84-243f67a6e410',
#  16: 'bf347fa3-7e8c-46d3-a6a7-1caa4551a10b',
#  17: 'f8d46e94-9ae4-4cd5-837e-f9c863746903',
#  18: 'a8c0f91e-4fcb-436c-b237-36bae0d2c2c2',
#  19: '46f5f586-0f1b-4ffb-9e0d-335e1a7d586a',
#  20: 'e1b60f2f-4f51-4ba1-975c-19c46e64a9b1',
# ...

# %%
# Vectors.get_by_ids(['41a9b714-4adf-467f-b1f8-b3170ea5547c'])

# %% [markdown]
# # Retrieval

# %%
Retriver = Vectors.as_retriever(search_type='similarity', search_kwargs={'k':5})

# %%
Retriver
# Out:
# VectorStoreRetriever(tags=['FAISS', 'GoogleGenerativeAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x0000022107016B10>, search_kwargs={'k': 5})

# %%
Retriver.invoke('Explain about Structured LLM outputs')
# Out:
# [Document(id='4b2770f1-7ba0-433e-8160-d1c16b033bc9', metadata={}, page_content='हेल्प करती हैं। बट यहां पे मैंने क्यों पढ़ाया? बिकॉज़ मैं आपको दिखाना चाहता था कि लैंग चेन में भी यह करना पॉसिबल है। करेंटली दिस इज पॉसिबल। आपको कोई रोक नहीं रहा है। इट्स जस्ट कि इट्स नॉट रिकमेंडेड कि आप लैंग चेन यूज़ करो। तो मैं बस आपको दिखाना चाहता था कि इट इज़ पॉसिबल टू क्रिएट एजेंट्स यूजिंग लंग चेन। एंड सेकंड थोड़ा सा आपको एक फ्लेवर देना था कि एआई एजेंट्स होते क्या है? बनाए कैसे जाते हैं? उनका वर्किंग कैसा होता है? यह सब कुछ आपको दिखाना चाहता था। तो आई रियली होप आपको यह सब कुछ देख के मजा आया। और ऑन द होल भी यह पूरी प्लेलिस्ट अगर आपने फॉलो की तो आई रियली होप लैंग चेंज जो कि अभी एक बहुत पॉपुलर लाइब्रेरी है। यह आप आसानी से समझ पाए। तो या इट हैज़ बीन अ ग्रेट जर्नी। थैंक यू अगर आपने सारे वीडियोस देखे और कमेंट किया, लाइक किया, शेयर किया। इस वीडियो को भी प्लीज लाइक करना अगर आपको पसंद आए। बाकी अगर आपने चैनल को सब्सक्राइब नहीं किया है, प्लीज डू सब्सक्राइब। मिलते हैं नेक्स्ट वीडियो में। बाई।'),
# ...

# %%
# Prompt

# %%
from langchain_core.prompts import PromptTemplate

# %%
Prompt = PromptTemplate(
    template="""
    
    You are a helpful assistant.
    Check the content is in english, if content is not in english just convert to english, but don't show the translation, if user question doesn't match in the translation content then say I Don't Insufficient data.
    Answer ONLY from the provided transcript context.
    If user ask to summarize the content provide meaningful summary.
    If the context is insufficient, just say you don't know.

    {context}
    Question: {question}
      
    """,
    input_variables=['context','question']
)

# %%
question          = "Explain RAGs"
retrieved_docs    = Retriver.invoke(question)

# %%
retrieved_docs
# Out:
# [Document(id='5f47d8c6-2684-437b-b639-7bc39274cb28', metadata={}, page_content='देन वी आर सेइंग कि यूज़ द फॉलोइंग फॉर्मेट। क्वेश्चन द इनपुट क्वेश्चन यू मस्ट आंसर थॉट यू शुड ऑलवेज थिंक अबाउट व्हाट टू डू। एक्शन द एक्शन टू टेक शुड बी वन ऑफ टूल नेम्स। सो कभी भी आप कोई एक्शन लोगे तो वो कोई टूल को यूज़ करके लोगे। फिर आप एक्शन को एक एक्शन इनपुट दोगे द इनपुट टू द एक्शन और फिर आपको एक ऑब्जरवेशन मिलेगा द रिजल्ट ऑफ द एक्शन और उसके बाद यहां पे लिखा हुआ है कि ये जो थॉट एक्शन एक्शन इनपुट ऑब्जरवेशन का लूप है ये n टाइम्स चल सकता है और रुकेगा कब जब आपका थॉट होगा आई नाउ नो द फाइनल आंसर और फिर आप फाइनल आंसर को प्रिंट कर दोगे और फिर यहां पे लिखा है बिगिन और आपने क्वेश्चन में अपना यूजर का क्वेरी भेज दिया और यहां थॉट में आपने अभी अभी तक जो भी थॉट का पूरा ये ट्रेस है वो आपने यहां पे भेज दिया। सो ये जो एजेंट स्क्रैच पैड है इसमें आप एग्जैक्टली ये चीज भेजते हो। अभी तक का जो प्रोग्रेस है ये फर्स्ट लूप के बाद ये सेकंड लूप के बाद। तो यह बड़ा होता चला जाता है हर लूप के बाद। ये पूरी चीज को आप हर बार भेज रहे हो। तो इ
# ...

# %%
retrieved_context = "\n\n".join(i.page_content for i in retrieved_docs)

# %%
retrieved_context
# Out:
# 'देन वी आर सेइंग कि यूज़ द फॉलोइंग फॉर्मेट। क्वेश्चन द इनपुट क्वेश्चन यू मस्ट आंसर थॉट यू शुड ऑलवेज थिंक अबाउट व्हाट टू डू। एक्शन द एक्शन टू टेक शुड बी वन ऑफ टूल नेम्स। सो कभी भी आप कोई एक्शन लोगे तो वो कोई टूल को यूज़ करके लोगे। फिर आप एक्शन को एक एक्शन इनपुट दोगे द इनपुट टू द एक्शन और फिर आपको एक ऑब्जरवेशन मिलेगा द रिजल्ट ऑफ द एक्शन और उसके बाद यहां पे लिखा हुआ है कि ये जो थॉट एक्शन एक्शन इनपुट ऑब्जरवेशन का लूप है ये n टाइम्स चल सकता है और रुकेगा कब जब आपका थॉट होगा आई नाउ नो द फाइनल आंसर और फिर आप फाइनल आंसर को प्रिंट कर दोगे और फिर यहां पे लिखा है बिगिन और आपने क्वेश्चन में अपना यूजर का क्वेरी भेज दिया और यहां थॉट में आपने अभी अभी तक जो भी थॉट का पूरा ये ट्रेस है वो आपने यहां पे भेज दिया। सो ये जो एजेंट स्क्रैच पैड है इसमें आप एग्जैक्टली ये चीज भेजते हो। अभी तक का जो प्रोग्रेस है ये फर्स्ट लूप के बाद ये सेकंड लूप के बाद। तो यह बड़ा होता चला जाता है हर लूप के बाद। ये पूरी चीज को आप हर बार भेज रहे हो। तो इन अ वे ये काइंड ऑफ मेमोरी मेंटेन करने के लिए है कि अभी तक एजेंट ने क्या-क्या कि
# ...

# %%
final_prompt = Prompt.invoke({'context':retrieved_context,'question':question})

# %%
final_prompt
# Out:
# StringPromptValue(text="\n    \n    You are a helpful assistant.\n    First greet the user.\n    Check the content is in english, if content is not in english just convert to english, but don't show the translation, if user question doesn't match in the translation content then say I Don't Insufficient data.\n    Answer ONLY from the provided transcript context.\n    If user ask to summarize the content provide meaningful summary.\n    If the context is insufficient, just say you don't know.\n\n    देन वी आर सेइंग कि यूज़ द फॉलोइंग फॉर्मेट। क्वेश्चन द इनपुट क्वेश्चन यू मस्ट आंसर थॉट यू शुड ऑलवेज थिंक अबाउट व्हाट टू डू। एक्शन द एक्शन टू टेक शुड बी वन ऑफ टूल नेम्स। सो कभी भी आप कोई एक्शन लोगे तो वो कोई टूल को यूज़ करके लोगे। फिर आप एक्शन को एक एक्शन इनपुट दोगे द इनपुट टू द एक्शन और फिर आपको एक ऑब्जरवेशन मिलेगा द रिजल्ट ऑफ द एक्शन और उसके बाद यहां पे लिखा हुआ है कि ये जो थॉट एक्शन एक्शन इनपुट ऑब्जरवेशन का लूप है ये n टाइम्स चल सकता है और रुकेगा कब जब आपका थॉट होगा आई नाउ नो द फाइनल आंसर औ
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    google_api_key='AIzaSyCoqxDqLb8NYnoUnaMyPrNz9Y5wrZZQzWo',
    temperature=0.5,
)

# %%
result = model.invoke(final_prompt)

# %%
result
# Out:
# AIMessage(content="Hello! I am here to help you.\n\nI don't have information about RAGs in the provided context.", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': []}, id='run--d0b31092-0305-4f94-994b-e710bf20bbd8-0', usage_metadata={'input_tokens': 2124, 'output_tokens': 25, 'total_tokens': 2149, 'input_token_details': {'cache_read': 0}})

# %%
print(result.content)
# Out:
# Hello! I am here to help you.
#
# I don't have information about RAGs in the provided context.

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
  retrieved_context = "\n\n".join(i.page_content for i in retrieved_docs)
  return retrieved_context

# %%
parallel_chain = RunnableParallel({
    'context': Retriver | RunnableLambda(format_docs),
    'question': RunnablePassthrough()
})

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | Prompt | model | parser

# %%
result = main_chain.invoke('who is sawamura')

# %%
print(result)
# Out:
# I don't know.

# %%
while True:
    user = input('You : ')
    if user == 'exit':
        print('Thank you for using our services. Hope i assisted you well')
        break
    result = main_chain.invoke(user)
    print('AI : ',result)

print(chat_history)
# Out:
# You :  Helo
# AI :  Hello! How can I help you today?
# You :  give me code
# AI :  I am sorry, I cannot provide you with the specific code from this transcript. The content explains how agents and agent executors implement the ReAct design pattern and how to import prompts from the Langchain hub, but it doesn't include the actual code.
# You :  explain in detail about agent and give some examples
# AI :  Hello!
#
# AI agents are intelligent systems that receive a high-level goal from a user and autonomously plan, decide, and execute a sequence of actions using external tools, APIs, or knowledge sources. They maintain context, reason over multiple steps, and adapt to new information.
#
# For example, imagine you have an AI agent installed on a website with a chat interface. You can provide a clear goal, such as "Can you create a budget travel itinerary from Delhi to Goa from the first to the seventh of May?" The AI agent will then:
#
# ...
